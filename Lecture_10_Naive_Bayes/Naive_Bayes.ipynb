# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.duplicated().sum())
# Out:
# (1218, 12)
# <class 'pandas.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             1218 non-null   int64
#  1   Sex             1218 non-null   str
#  2   ChestPainType   1218 non-null   str
#  3   RestingBP       1218 non-null   int64
#  4   Cholesterol     1218 non-null   int64
#  5   FastingBS       1218 non-null   int64
#  6   RestingECG      1218 non-null   str
#  7   MaxHR           1218 non-null   int64
#  8   ExerciseAngina  1218 non-null   str
#  9   Oldpeak         1218 non-null   float64
#  10  ST_Slope        1218 non-null   str
#  11  HeartDisease    1218 non-null   int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 129.4 KB
# None
#                Age    RestingBP  Cholesterol    FastingBS        MaxHR  \
# count  1218.000000  1218.000000  1218.000000  1218.000000  1218.000000
# mean     53.370279   132.904762   210.573071     0.229064   136.686371
# std       9.359698    18.292900   101.353997     0.420403    25.221194
# min      28.000000     0.000000     0.000000     0.000000    60.000000
# 25%      47.000000   120.000000   184.000000     0.000000   120.000000
# 50%      54.000000   130.000000   230.000000     0.000000   138.000000
# 75%      60.000000   143.000000   271.000000     0.000000   155.000000
# max      80.000000   200.000000   603.000000     1.000000   202.000000
#
#            Oldpeak  HeartDisease
# count  1218.000000   1218.000000
# mean      0.941051      0.513136
# std       1.015641      0.500033
# min      -2.600000      0.000000
# 25%       0.000000      0.000000
# 50%       0.800000      1.000000
# 75%       1.500000      1.000000
# max       6.200000      1.000000
# 0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
plt.title('Distribution of Heart Disease')
plt.xlabel('Heart Disease')
plt.ylabel('Count')
plt.show()

# %%
# Plot between ChestPainType and HeartDisease
sns.countplot(x='ChestPainType', hue='HeartDisease', data=df)
plt.title('Chest Pain Type vs Heart Disease')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %%
sns.countplot(x = df['FastingBS'],hue = df['HeartDisease'])
plt.title('Fasting Blood Sugar vs Heart Disease')
plt.xlabel('Fasting Blood Sugar')
plt.ylabel('Count')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %%
sns.boxplot(x = df['HeartDisease'],y = df['Age'])
plt.title('Age vs Heart Disease')
plt.xlabel('Heart Disease')
plt.ylabel('Age')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded
# Out:
#       Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0      40        140          289          0    172      0.0             0
# 1      49        160          180          0    156      1.0             1
# 2      37        130          283          0     98      0.0             0
# 3      48        138          214          0    108      1.5             1
# 4      54        150          195          0    122      0.0             0
# ...   ...        ...          ...        ...    ...      ...           ...
# 1213   46        100          187          0    176      0.1             1
# 1214   61        125          315          0    105      1.5             0
# 1215   56        111          235          0     99      0.1             0
# 1216   61        108          243          1    141      1.4             0
# 1217   59        153          189          0    138      0.6             0
#
#       Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      True               True              False             False
# 1     False              False               True             False
# 2      True               True              False             False
# 3     False              False              False             False
# 4      True              False               True             False
# ...     ...                ...                ...               ...
# 1213   True              False              False             False
# 1214   True               True              False             False
# 1215   True               True              False             False
# 1216  False              False               True             False
# 1217   True               True              False             False
#
#       RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                  True          False             False          False
# 1                  True          False             False           True
# 2                 False           True             False          False
# 3                  True          False              True           True
# 4                  True          False             False          False
# ...                 ...            ...               ...            ...
# 1213               True          False              True          False
# 1214               True          False             False          False
# 1215               True          False              True          False
# 1216               True          False             False          False
# 1217               True          False              True          False
#
#       ST_Slope_Up
# 0            True
# 1           False
# 2            True
# 3           False
# 4            True
# ...           ...
# 1213         True
# 1214         True
# 1215         True
# 1216         True
# 1217         True
#
# [1218 rows x 16 columns]

# %%
df_encoded = df_encoded.astype(int)

# %%
df_encoded.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172        0             0
# 1   49        160          180          0    156        1             1
# 2   37        130          283          0     98        0             0
# 3   48        138          214          0    108        1             1
# 4   54        150          195          0    122        0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                  1              0                 0              0
# 1                  1              0                 0              1
# 2                  0              1                 0              0
# 3                  1              0                 1              1
# 4                  1              0                 0              0
#
#    ST_Slope_Up
# 0            1
# 1            0
# 2            1
# 3            0
# 4            1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
